# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /home/grazia/miniconda3/lib/python3.9/site-packages (2.1.1)
# Requirement already satisfied: numpy>=1.22.4 in /home/grazia/miniconda3/lib/python3.9/site-packages (from pandas) (1.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/grazia/miniconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/grazia/miniconda3/lib/python3.9/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/grazia/miniconda3/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/grazia/miniconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lxml
# Out:
# Requirement already satisfied: lxml in /home/grazia/miniconda3/lib/python3.9/site-packages (4.9.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xlrd
# Out:
# Requirement already satisfied: xlrd in /home/grazia/miniconda3/lib/python3.9/site-packages (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /home/grazia/miniconda3/lib/python3.9/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /home/grazia/miniconda3/lib/python3.9/site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

# %%
import xlrd
df = pd.read_excel('T1.xlsx', sheet_name='h2')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            151         0       2
# 1            152         1       1
# 2            153         0       3
# 3            154         0       3
# 4            155         0       3
# ..           ...       ...     ...
# 145          296         0       1
# 146          297         0       3
# 147          298         0       1
# 148          299         1       1
# 149          300         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                         Bateman, Rev. Robert James    male  51.0      0
# 1                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1
# 2                                   Meo, Mr. Alfonzo    male  55.5      0
# 3                    van Billiard, Mr. Austin Blyler    male  40.5      0
# 4                              Olsen, Mr. Ole Martin    male   NaN      0
# ..                                               ...     ...   ...    ...
# 145                                Lewy, Mr. Ervin G    male   NaN      0
# 146                               Hanna, Mr. Mansour    male  23.5      0
# 147                     Allison, Miss. Helen Loraine  female   2.0      1
# 148                            Saalfeld, Mr. Adolphe    male   NaN      0
# 149  Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0      0
#
#      Parch       Ticket      Fare    Cabin Embarked
# 0        0  S.O.P. 1166   12.5250      NaN        S
# 1        0       113776   66.6000       C2        S
# 2        0   A.5. 11206    8.0500      NaN        S
# 3        2     A/5. 851   14.5000      NaN        S
# 4        0    Fa 265302    7.3125      NaN        S
# ..     ...          ...       ...      ...      ...
# 145      0     PC 17612   27.7208      NaN        C
# 146      0         2693    7.2292      NaN        C
# 147      2       113781  151.5500  C22 C26        S
# 148      0        19988   30.5000     C106        S
# 149      1     PC 17558  247.5208  B58 B60        C
#
# [150 rows x 12 columns]

# %%
import xlrd
df1 = pd.read_excel('T1.xlsx', sheet_name='h1')
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 145          146         0       2
# 146          147         1       3
# 147          148         0       3
# 148          149         0       2
# 149          150         0       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 145                       Nicholls, Mr. Joseph Charles    male  19.0      1
# 146       Andersson, Mr. August Edvard ("Wennerstrom")    male  27.0      0
# 147                   Ford, Miss. Robina Maggie "Ruby"  female   9.0      2
# 148           Navratil, Mr. Michel ("Louis M Hoffman")    male  36.5      0
# 149                  Byles, Rev. Thomas Roussel Davids    male  42.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 145      1        C.A. 33112  36.7500   NaN        S
# 146      0            350043   7.7958   NaN        S
# 147      2        W./C. 6608  34.3750   NaN        S
# 148      2            230080  26.0000    F2        S
# 149      0            244310  13.0000   NaN        S
#
# [150 rows x 12 columns]

# %%
df2 = pd.read_csv('T2.csv', encoding ='utf-8')
df2
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0            301         1       3  Kelly, Miss. Anna Katherine "Annie Kate"
# 1            302         1       3                        McCoy, Mr. Bernard
# 2            303         0       3           Johnson, Mr. William Cahoone Jr
# 3            304         1       2                       Keane, Miss. Nora A
# 4            305         0       3         Williams, Mr. Howard Hugh "Harry"
# ..           ...       ...     ...                                       ...
# 145          446         1       1                 Dodge, Master. Washington
# 146          447         1       2         Mellinger, Miss. Madeleine Violet
# 147          448         1       1               Seward, Mr. Frederic Kimber
# 148          449         1       3            Baclini, Miss. Marie Catherine
# 149          450         1       1            Peuchen, Major. Arthur Godfrey
#
#         Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 0    female   NaN      0      0      9234   7.7500   NaN        Q
# 1      male   NaN      2      0    367226  23.2500   NaN        Q
# 2      male  19.0      0      0      LINE   0.0000   NaN        S
# 3    female   NaN      0      0    226593  12.3500  E101        Q
# 4      male   NaN      0      0  A/5 2466   8.0500   NaN        S
# ..      ...   ...    ...    ...       ...      ...   ...      ...
# 145    male   4.0      0      2     33638  81.8583   A34        S
# 146  female  13.0      0      1    250644  19.5000   NaN        S
# 147    male  34.0      0      0    113794  26.5500   NaN        S
# 148  female   5.0      2      1      2666  19.2583   NaN        C
# 149    male  52.0      0      0    113786  30.5000  C104        S
#
# [150 rows x 12 columns]

# %%
df3 = pd.read_xml('T3.xml', encoding ='utf-8')
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0            451         0       2
# 1            452         0       3
# 2            453         0       1
# 3            454         1       1
# 4            455         0       3
# ..           ...       ...     ...
# 145          596         0       3
# 146          597         1       2
# 147          598         0       3
# 148          599         0       3
# 149          600         1       1
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                           West, Mr. Edwy Arthur    male  36.0      1      2
# 1                 Hagland, Mr. Ingvald Olai Olsen    male   NaN      1      0
# 2                 Foreman, Mr. Benjamin Laventall    male  30.0      0      0
# 3                        Goldenberg, Mr. Samuel L    male  49.0      1      0
# 4                             Peduzzi, Mr. Joseph    male   NaN      0      0
# ..                                            ...     ...   ...    ...    ...
# 145                   Van Impe, Mr. Jean Baptiste    male  36.0      1      1
# 146                    Leitch, Miss. Jessie Wills  female   NaN      0      0
# 147                           Johnson, Mr. Alfred    male  49.0      0      0
# 148                             Boulos, Mr. Hanna    male   NaN      0      0
# 149  Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")    male  49.0      1      0
#
#          Ticket     Fare Cabin Embarked
# 0    C.A. 34651  27.7500  None        S
# 1         65303  19.9667  None        S
# 2        113051  27.7500  C111        C
# 3         17453  89.1042   C92        C
# 4      A/5 2817   8.0500  None        S
# ..          ...      ...   ...      ...
# 145      345773  24.1500  None        S
# 146      248727  33.0000  None        S
# 147        LINE   0.0000  None        S
# 148        2664   7.2250  None        C
# 149    PC 17485  56.9292   A20        C
#
# [150 rows x 12 columns]

# %%
df4 = pd.read_csv('T4.csv', sep= ';')
df4
# Out:
#      PassengerId  Survived  Pclass  \
# 0            601         1       2
# 1            602         0       3
# 2            603         0       1
# 3            604         0       3
# 4            605         1       1
# ..           ...       ...     ...
# 144          745         1       3
# 145          746         0       1
# 146          747         0       3
# 147          748         1       2
# 148          749         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0    Jacobsohn; Mrs. Sidney Samuel (Amy Frances Chr...  female  24.0      2
# 1                                 Slabenoff; Mr. Petco    male   NaN      0
# 2                            Harrington; Mr. Charles H    male   NaN      0
# 3                            Torber; Mr. Ernst William    male  44.0      0
# 4                      Homer; Mr. Harry ("Mr E Haven")    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 144                                 Stranden; Mr. Juho    male  31.0      0
# 145                       Crosby; Capt. Edward Gifford    male  70.0      1
# 146                        Abbott; Mr. Rossmore Edward    male  16.0      1
# 147                              Sinkkonen; Miss. Anna  female  30.0      0
# 148                          Marvin; Mr. Daniel Warner    male  19.0      1
#
#      Parch             Ticket     Fare Cabin Embarked
# 0        1             243847  27.0000   NaN        S
# 1        0             349214   7.8958   NaN        S
# 2        0             113796  42.4000   NaN        S
# 3        0             364511   8.0500   NaN        S
# 4        0             111426  26.5500   NaN        C
# ..     ...                ...      ...   ...      ...
# 144      0  STON/O 2. 3101288   7.9250   NaN        S
# 145      1          WE/P 5735  71.0000   B22        S
# 146      1          C.A. 2673  20.2500   NaN        S
# 147      0             250648  13.0000   NaN        S
# 148      0             113773  53.1000   D30        S
#
# [149 rows x 12 columns]

# %%
import xml.etree.ElementTree as et

# %%
df5 = pd.read_csv('T5.txt', sep='\t', encoding ='utf-8')
df5
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0            750         0       3                   Connaghton, Mr. Michael
# 1            751         1       2                         Wells, Miss. Joan
# 2            752         1       3                       Moor, Master. Meier
# 3            753         0       3          Vande Velde, Mr. Johannes Joseph
# 4            754         0       3                        Jonkoff, Mr. Lalio
# ..           ...       ...     ...                                       ...
# 137          887         0       2                     Montvila, Rev. Juozas
# 138          888         1       1              Graham, Miss. Margaret Edith
# 139          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 140          890         1       1                     Behr, Mr. Karl Howell
# 141          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 0      male  31.0      0      0      335097   7.7500   NaN        Q
# 1    female   4.0      1      1       29103  23.0000   NaN        S
# 2      male   6.0      0      1      392096  12.4750  E121        S
# 3      male  33.0      0      0      345780   9.5000   NaN        S
# 4      male  23.0      0      0      349204   7.8958   NaN        S
# ..      ...   ...    ...    ...         ...      ...   ...      ...
# 137    male  27.0      0      0      211536  13.0000   NaN        S
# 138  female  19.0      0      0      112053  30.0000   B42        S
# 139  female   NaN      1      2  W./C. 6607  23.4500   NaN        S
# 140    male  26.0      0      0      111369  30.0000  C148        C
# 141    male  32.0      0      0      370376   7.7500   NaN        Q
#
# [142 rows x 12 columns]

# %%
df6 = pd.read_csv('T6', sep=',', encoding ='utf-8')
df6
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
df.set_index('PassengerId',inplace=True)
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 151                 0       2
# 152                 1       1
# 153                 0       3
# 154                 0       3
# 155                 0       3
# ...               ...     ...
# 296                 0       1
# 297                 0       3
# 298                 0       1
# 299                 1       1
# 300                 1       1
#
#                                                         Name     Sex   Age  \
# PassengerId
# 151                               Bateman, Rev. Robert James    male  51.0
# 152                        Pears, Mrs. Thomas (Edith Wearne)  female  22.0
# 153                                         Meo, Mr. Alfonzo    male  55.5
# 154                          van Billiard, Mr. Austin Blyler    male  40.5
# 155                                    Olsen, Mr. Ole Martin    male   NaN
# ...                                                      ...     ...   ...
# 296                                        Lewy, Mr. Ervin G    male   NaN
# 297                                       Hanna, Mr. Mansour    male  23.5
# 298                             Allison, Miss. Helen Loraine  female   2.0
# 299                                    Saalfeld, Mr. Adolphe    male   NaN
# 300          Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0
#
#              SibSp  Parch       Ticket      Fare    Cabin Embarked
# PassengerId
# 151              0      0  S.O.P. 1166   12.5250      NaN        S
# 152              1      0       113776   66.6000       C2        S
# 153              0      0   A.5. 11206    8.0500      NaN        S
# 154              0      2     A/5. 851   14.5000      NaN        S
# 155              0      0    Fa 265302    7.3125      NaN        S
# ...            ...    ...          ...       ...      ...      ...
# 296              0      0     PC 17612   27.7208      NaN        C
# 297              0      0         2693    7.2292      NaN        C
# 298              1      2       113781  151.5500  C22 C26        S
# 299              0      0        19988   30.5000     C106        S
# 300              0      1     PC 17558  247.5208  B58 B60        C
#
# [150 rows x 11 columns]

# %%
df1.set_index('PassengerId',inplace=True)
df1
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 146                 0       2
# 147                 1       3
# 148                 0       3
# 149                 0       2
# 150                 0       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 146                               Nicholls, Mr. Joseph Charles    male  19.0
# 147               Andersson, Mr. August Edvard ("Wennerstrom")    male  27.0
# 148                           Ford, Miss. Robina Maggie "Ruby"  female   9.0
# 149                   Navratil, Mr. Michel ("Louis M Hoffman")    male  36.5
# 150                          Byles, Rev. Thomas Roussel Davids    male  42.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 146              1      1        C.A. 33112  36.7500   NaN        S
# 147              0      0            350043   7.7958   NaN        S
# 148              2      2        W./C. 6608  34.3750   NaN        S
# 149              0      2            230080  26.0000    F2        S
# 150              0      0            244310  13.0000   NaN        S
#
# [150 rows x 11 columns]

# %%
df2.set_index('PassengerId',inplace=True)
df2
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 301                 1       3  Kelly, Miss. Anna Katherine "Annie Kate"
# 302                 1       3                        McCoy, Mr. Bernard
# 303                 0       3           Johnson, Mr. William Cahoone Jr
# 304                 1       2                       Keane, Miss. Nora A
# 305                 0       3         Williams, Mr. Howard Hugh "Harry"
# ...               ...     ...                                       ...
# 446                 1       1                 Dodge, Master. Washington
# 447                 1       2         Mellinger, Miss. Madeleine Violet
# 448                 1       1               Seward, Mr. Frederic Kimber
# 449                 1       3            Baclini, Miss. Marie Catherine
# 450                 1       1            Peuchen, Major. Arthur Godfrey
#
#                 Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# PassengerId
# 301          female   NaN      0      0      9234   7.7500   NaN        Q
# 302            male   NaN      2      0    367226  23.2500   NaN        Q
# 303            male  19.0      0      0      LINE   0.0000   NaN        S
# 304          female   NaN      0      0    226593  12.3500  E101        Q
# 305            male   NaN      0      0  A/5 2466   8.0500   NaN        S
# ...             ...   ...    ...    ...       ...      ...   ...      ...
# 446            male   4.0      0      2     33638  81.8583   A34        S
# 447          female  13.0      0      1    250644  19.5000   NaN        S
# 448            male  34.0      0      0    113794  26.5500   NaN        S
# 449          female   5.0      2      1      2666  19.2583   NaN        C
# 450            male  52.0      0      0    113786  30.5000  C104        S
#
# [150 rows x 11 columns]

# %%
df3.set_index('PassengerId',inplace=True)
df3
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 451                 0       2                         West, Mr. Edwy Arthur
# 452                 0       3               Hagland, Mr. Ingvald Olai Olsen
# 453                 0       1               Foreman, Mr. Benjamin Laventall
# 454                 1       1                      Goldenberg, Mr. Samuel L
# 455                 0       3                           Peduzzi, Mr. Joseph
# ...               ...     ...                                           ...
# 596                 0       3                   Van Impe, Mr. Jean Baptiste
# 597                 1       2                    Leitch, Miss. Jessie Wills
# 598                 0       3                           Johnson, Mr. Alfred
# 599                 0       3                             Boulos, Mr. Hanna
# 600                 1       1  Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")
#
#                 Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# PassengerId
# 451            male  36.0      1      2  C.A. 34651  27.7500  None        S
# 452            male   NaN      1      0       65303  19.9667  None        S
# 453            male  30.0      0      0      113051  27.7500  C111        C
# 454            male  49.0      1      0       17453  89.1042   C92        C
# 455            male   NaN      0      0    A/5 2817   8.0500  None        S
# ...             ...   ...    ...    ...         ...      ...   ...      ...
# 596            male  36.0      1      1      345773  24.1500  None        S
# 597          female   NaN      0      0      248727  33.0000  None        S
# 598            male  49.0      0      0        LINE   0.0000  None        S
# 599            male   NaN      0      0        2664   7.2250  None        C
# 600            male  49.0      1      0    PC 17485  56.9292   A20        C
#
# [150 rows x 11 columns]

# %%
df4.set_index('PassengerId',inplace=True)
df4
# Out:
#              Survived  Pclass  \
# PassengerId
# 601                 1       2
# 602                 0       3
# 603                 0       1
# 604                 0       3
# 605                 1       1
# ...               ...     ...
# 745                 1       3
# 746                 0       1
# 747                 0       3
# 748                 1       2
# 749                 0       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 601          Jacobsohn; Mrs. Sidney Samuel (Amy Frances Chr...  female  24.0
# 602                                       Slabenoff; Mr. Petco    male   NaN
# 603                                  Harrington; Mr. Charles H    male   NaN
# 604                                  Torber; Mr. Ernst William    male  44.0
# 605                            Homer; Mr. Harry ("Mr E Haven")    male  35.0
# ...                                                        ...     ...   ...
# 745                                         Stranden; Mr. Juho    male  31.0
# 746                               Crosby; Capt. Edward Gifford    male  70.0
# 747                                Abbott; Mr. Rossmore Edward    male  16.0
# 748                                      Sinkkonen; Miss. Anna  female  30.0
# 749                                  Marvin; Mr. Daniel Warner    male  19.0
#
#              SibSp  Parch             Ticket     Fare Cabin Embarked
# PassengerId
# 601              2      1             243847  27.0000   NaN        S
# 602              0      0             349214   7.8958   NaN        S
# 603              0      0             113796  42.4000   NaN        S
# 604              0      0             364511   8.0500   NaN        S
# 605              0      0             111426  26.5500   NaN        C
# ...            ...    ...                ...      ...   ...      ...
# 745              0      0  STON/O 2. 3101288   7.9250   NaN        S
# 746              1      1          WE/P 5735  71.0000   B22        S
# 747              1      1          C.A. 2673  20.2500   NaN        S
# 748              0      0             250648  13.0000   NaN        S
# 749              1      0             113773  53.1000   D30        S
#
# [149 rows x 11 columns]

# %%
df5.set_index('PassengerId',inplace=True)
df5
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 750                 0       3                   Connaghton, Mr. Michael
# 751                 1       2                         Wells, Miss. Joan
# 752                 1       3                       Moor, Master. Meier
# 753                 0       3          Vande Velde, Mr. Johannes Joseph
# 754                 0       3                        Jonkoff, Mr. Lalio
# ...               ...     ...                                       ...
# 887                 0       2                     Montvila, Rev. Juozas
# 888                 1       1              Graham, Miss. Margaret Edith
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                     Behr, Mr. Karl Howell
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# PassengerId
# 750            male  31.0      0      0      335097   7.7500   NaN        Q
# 751          female   4.0      1      1       29103  23.0000   NaN        S
# 752            male   6.0      0      1      392096  12.4750  E121        S
# 753            male  33.0      0      0      345780   9.5000   NaN        S
# 754            male  23.0      0      0      349204   7.8958   NaN        S
# ...             ...   ...    ...    ...         ...      ...   ...      ...
# 887            male  27.0      0      0      211536  13.0000   NaN        S
# 888          female  19.0      0      0      112053  30.0000   B42        S
# 889          female   NaN      1      2  W./C. 6607  23.4500   NaN        S
# 890            male  26.0      0      0      111369  30.0000  C148        C
# 891            male  32.0      0      0      370376   7.7500   NaN        Q
#
# [142 rows x 11 columns]

# %%
df6.set_index('PassengerId',inplace=True)
df6
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...             ...                                           ...     ...
# 1305              3                            Spector, Mr. Woolf    male
# 1306              1                  Oliva y Ocana, Dona. Fermina  female
# 1307              3                  Saether, Mr. Simon Sivertsen    male
# 1308              3                           Ware, Mr. Frederick    male
# 1309              3                      Peter, Master. Michael J    male
#
#               Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# PassengerId
# 892          34.5      0      0              330911    7.8292   NaN        Q
# 893          47.0      1      0              363272    7.0000   NaN        S
# 894          62.0      0      0              240276    9.6875   NaN        Q
# 895          27.0      0      0              315154    8.6625   NaN        S
# 896          22.0      1      1             3101298   12.2875   NaN        S
# ...           ...    ...    ...                 ...       ...   ...      ...
# 1305          NaN      0      0           A.5. 3236    8.0500   NaN        S
# 1306         39.0      0      0            PC 17758  108.9000  C105        C
# 1307         38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1308          NaN      0      0              359309    8.0500   NaN        S
# 1309          NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 10 columns]

# %%
df_list = pd.concat([df,df1, df2,df3, df4, df5, df6])

# %%
df_list.sort_values(by='PassengerId',inplace = True)
df_list
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                 0.0       3
# 2                 1.0       1
# 3                 1.0       3
# 4                 1.0       1
# 5                 0.0       3
# ...               ...     ...
# 1305              NaN       3
# 1306              NaN       1
# 1307              NaN       3
# 1308              NaN       3
# 1309              NaN       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 1305                                        Spector, Mr. Woolf    male   NaN
# 1306                              Oliva y Ocana, Dona. Fermina  female  39.0
# 1307                              Saether, Mr. Simon Sivertsen    male  38.5
# 1308                                       Ware, Mr. Frederick    male   NaN
# 1309                                  Peter, Master. Michael J    male   NaN
#
#              SibSp  Parch              Ticket      Fare Cabin Embarked
# PassengerId
# 1                1      0           A/5 21171    7.2500   NaN        S
# 2                1      0            PC 17599   71.2833   C85        C
# 3                0      0    STON/O2. 3101282    7.9250   NaN        S
# 4                1      0              113803   53.1000  C123        S
# 5                0      0              373450    8.0500   NaN        S
# ...            ...    ...                 ...       ...   ...      ...
# 1305             0      0           A.5. 3236    8.0500   NaN        S
# 1306             0      0            PC 17758  108.9000  C105        C
# 1307             0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1308             0      0              359309    8.0500   NaN        S
# 1309             1      1                2668   22.3583   NaN        C
#
# [1309 rows x 11 columns]

# %%
df_list2 = df_list.copy()
df_list2
df_list2.to_csv('titanic2.0.csv', index=False)

# %% [markdown]
# ## 1.- tipo de características (columnas)

# %%
df_list.shape  # Indica el numero de filas y columnas
# Out:
# (1309, 11)

# %%
df_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1309 entries, 1 to 1309
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    float64
#  1   Pclass    1309 non-null   int64
#  2   Name      1309 non-null   object
#  3   Sex       1309 non-null   object
#  4   Age       1046 non-null   float64
#  5   SibSp     1309 non-null   int64
#  6   Parch     1309 non-null   int64
#  7   Ticket    1309 non-null   object
#  8   Fare      1308 non-null   float64
#  9   Cabin     295 non-null    object
#  10  Embarked  1307 non-null   object
# dtypes: float64(3), int64(3), object(5)
# memory usage: 122.7+ KB

# %% [markdown]
# ## 2.- 5 primeros elementos

# %%
df_list.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                 0.0       3
# 2                 1.0       1
# 3                 1.0       3
# 4                 1.0       1
# 5                 0.0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %% [markdown]
# ## 3.- una muestra de 10 registros

# %%
df_list.head(10)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                 0.0       3
# 2                 1.0       1
# 3                 1.0       3
# 4                 1.0       1
# 5                 0.0       3
# 6                 0.0       3
# 7                 0.0       1
# 8                 0.0       3
# 9                 1.0       3
# 10                1.0       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 8                               Palsson, Master. Gosta Leonard    male   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# 6                0      0            330877   8.4583   NaN        Q
# 7                0      0             17463  51.8625   E46        S
# 8                3      1            349909  21.0750   NaN        S
# 9                0      2            347742  11.1333   NaN        S
# 10               1      0            237736  30.0708   NaN        C

# %% [markdown]
# ## 4.- Indexar por ID_Pasajero

# %%
df_list
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                 0.0       3
# 2                 1.0       1
# 3                 1.0       3
# 4                 1.0       1
# 5                 0.0       3
# ...               ...     ...
# 1305              NaN       3
# 1306              NaN       1
# 1307              NaN       3
# 1308              NaN       3
# 1309              NaN       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 1305                                        Spector, Mr. Woolf    male   NaN
# 1306                              Oliva y Ocana, Dona. Fermina  female  39.0
# 1307                              Saether, Mr. Simon Sivertsen    male  38.5
# 1308                                       Ware, Mr. Frederick    male   NaN
# 1309                                  Peter, Master. Michael J    male   NaN
#
#              SibSp  Parch              Ticket      Fare Cabin Embarked
# PassengerId
# 1                1      0           A/5 21171    7.2500   NaN        S
# 2                1      0            PC 17599   71.2833   C85        C
# 3                0      0    STON/O2. 3101282    7.9250   NaN        S
# 4                1      0              113803   53.1000  C123        S
# 5                0      0              373450    8.0500   NaN        S
# ...            ...    ...                 ...       ...   ...      ...
# 1305             0      0           A.5. 3236    8.0500   NaN        S
# 1306             0      0            PC 17758  108.9000  C105        C
# 1307             0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1308             0      0              359309    8.0500   NaN        S
# 1309             1      1                2668   22.3583   NaN        C
#
# [1309 rows x 11 columns]

# %% [markdown]
# ## 5.- Verificar datos nulos

# %%
df_list.isnull().sum()
# Out:
# Survived     418
# Pclass         0
# Name           0
# Sex            0
# Age          263
# SibSp          0
# Parch          0
# Ticket         0
# Fare           1
# Cabin       1014
# Embarked       2
# dtype: int64

# %%
## 6.- Verificar datos duplicados

# %%
df_list.duplicated()
# Out:
# PassengerId
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 1305    False
# 1306    False
# 1307    False
# 1308    False
# 1309    False
# Length: 1309, dtype: bool

# %%
df_list.drop_duplicates()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                 0.0       3
# 2                 1.0       1
# 3                 1.0       3
# 4                 1.0       1
# 5                 0.0       3
# ...               ...     ...
# 1305              NaN       3
# 1306              NaN       1
# 1307              NaN       3
# 1308              NaN       3
# 1309              NaN       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 1305                                        Spector, Mr. Woolf    male   NaN
# 1306                              Oliva y Ocana, Dona. Fermina  female  39.0
# 1307                              Saether, Mr. Simon Sivertsen    male  38.5
# 1308                                       Ware, Mr. Frederick    male   NaN
# 1309                                  Peter, Master. Michael J    male   NaN
#
#              SibSp  Parch              Ticket      Fare Cabin Embarked
# PassengerId
# 1                1      0           A/5 21171    7.2500   NaN        S
# 2                1      0            PC 17599   71.2833   C85        C
# 3                0      0    STON/O2. 3101282    7.9250   NaN        S
# 4                1      0              113803   53.1000  C123        S
# 5                0      0              373450    8.0500   NaN        S
# ...            ...    ...                 ...       ...   ...      ...
# 1305             0      0           A.5. 3236    8.0500   NaN        S
# 1306             0      0            PC 17758  108.9000  C105        C
# 1307             0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1308             0      0              359309    8.0500   NaN        S
# 1309             1      1                2668   22.3583   NaN        C
#
# [1309 rows x 11 columns]

# %% [markdown]
# ## 7.- Separar y eliminar del df la columna target (separar la columna target y eliminarla del dataframe)

# %%
target_copy = df_list.copy()
target = target_copy['Survived']
target
# Out:
# PassengerId
# 1       0.0
# 2       1.0
# 3       1.0
# 4       1.0
# 5       0.0
#        ...
# 1305    NaN
# 1306    NaN
# 1307    NaN
# 1308    NaN
# 1309    NaN
# Name: Survived, Length: 1309, dtype: float64

# %%
df_list_copy2 = df_list.copy()

# %%
df_list = df_list.drop('Survived', axis=1)
df_list
# Out:
#              Pclass                                               Name  \
# PassengerId
# 1                 3                            Braund, Mr. Owen Harris
# 2                 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                 3                             Heikkinen, Miss. Laina
# 4                 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                 3                           Allen, Mr. William Henry
# ...             ...                                                ...
# 1305              3                                 Spector, Mr. Woolf
# 1306              1                       Oliva y Ocana, Dona. Fermina
# 1307              3                       Saether, Mr. Simon Sivertsen
# 1308              3                                Ware, Mr. Frederick
# 1309              3                           Peter, Master. Michael J
#
#                 Sex   Age  SibSp  Parch              Ticket      Fare Cabin  \
# PassengerId
# 1              male  22.0      1      0           A/5 21171    7.2500   NaN
# 2            female  38.0      1      0            PC 17599   71.2833   C85
# 3            female  26.0      0      0    STON/O2. 3101282    7.9250   NaN
# 4            female  35.0      1      0              113803   53.1000  C123
# 5              male  35.0      0      0              373450    8.0500   NaN
# ...             ...   ...    ...    ...                 ...       ...   ...
# 1305           male   NaN      0      0           A.5. 3236    8.0500   NaN
# 1306         female  39.0      0      0            PC 17758  108.9000  C105
# 1307           male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN
# 1308           male   NaN      0      0              359309    8.0500   NaN
# 1309           male   NaN      1      1                2668   22.3583   NaN
#
#             Embarked
# PassengerId
# 1                  S
# 2                  C
# 3                  S
# 4                  S
# 5                  S
# ...              ...
# 1305               S
# 1306               C
# 1307               S
# 1308               S
# 1309               C
#
# [1309 rows x 10 columns]

# %% [markdown]
# ## 8.- Eliminar columnas categoricas no importantes

# %%
df_list = df_list.drop(['Name','Cabin','Ticket'], axis=1)
df_list
# Out:
#              Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# PassengerId
# 1                 3    male  22.0      1      0    7.2500        S
# 2                 1  female  38.0      1      0   71.2833        C
# 3                 3  female  26.0      0      0    7.9250        S
# 4                 1  female  35.0      1      0   53.1000        S
# 5                 3    male  35.0      0      0    8.0500        S
# ...             ...     ...   ...    ...    ...       ...      ...
# 1305              3    male   NaN      0      0    8.0500        S
# 1306              1  female  39.0      0      0  108.9000        C
# 1307              3    male  38.5      0      0    7.2500        S
# 1308              3    male   NaN      0      0    8.0500        S
# 1309              3    male   NaN      1      1   22.3583        C
#
# [1309 rows x 7 columns]

# %%
df_list
# Out:
#              Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# PassengerId
# 1                 3    male  22.0      1      0    7.2500        S
# 2                 1  female  38.0      1      0   71.2833        C
# 3                 3  female  26.0      0      0    7.9250        S
# 4                 1  female  35.0      1      0   53.1000        S
# 5                 3    male  35.0      0      0    8.0500        S
# ...             ...     ...   ...    ...    ...       ...      ...
# 1305              3    male   NaN      0      0    8.0500        S
# 1306              1  female  39.0      0      0  108.9000        C
# 1307              3    male  38.5      0      0    7.2500        S
# 1308              3    male   NaN      0      0    8.0500        S
# 1309              3    male   NaN      1      1   22.3583        C
#
# [1309 rows x 7 columns]
